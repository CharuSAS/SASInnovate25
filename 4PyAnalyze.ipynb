# %% [markdown]
# Queen Bee’s Pattern Parade:
# 👑🐝 The Queen Bee is on a mission to find the sweetest bee names with the best patterns! while SAS flexed its data-handling muscles to reveal hidden patterns, watch as Python weaves its web of regex wizadry. Which tool will uncover the juiciest insights or are they both equal? Let the name hunt begin!

# %% [markdown]
# To obey the queen, we will find all instances of bee names ending in 'ern' 'ed' or with a '-' using perl regular expression.

# %%
import pandas as pd
import re

# Read the scientific and common name lookup csv file into a DataFrame
df3=pd.read_csv('/workspaces/myfolder/SASInnovate25/Bumblebee_Others_Scientific_Common_Names.csv' , encoding='latin-1')

# %% [markdown]
# re is a standard library module (or "package") in Python that provides support for regular expressions—a powerful way to search, match, and manipulate strings based on patterns.
#
# Since it's built into Python, you don't need to install it separately—just import re, and you're ready to start buzzing through text with regex! 🐝

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ScientificName   162 non-null    object
#  1   Species          162 non-null    object
#  2   specificEpithet  156 non-null    object
#  3   CommonName       162 non-null    object
#  4   Description      161 non-null    object
#  5   Source           161 non-null    object
# dtypes: object(6)
# memory usage: 7.7+ KB

# %% [markdown]
# DataFrames can be filtered in multiple ways; the most intuitive of which boolean indexing creating a series of True/False values.

# %%
#  regex pattern (case-insensitive and end-of-word)
pattern = r'(?i)\b(?:ed|ern)\b|-'  # (?i) = ignore case, \b = word boundary

# Apply the filter
df_regex = df3[df3['CommonName'].str.contains(pattern, regex=True)]

# Display the filtered DataFrame
print(df_regex)
# Out:
#                ScientificName       Species specificEpithet  \
# 29           Bombus appositus        Bombus       appositus
# 33           Bombus balteatus        Bombus       balteatus
# 34            Bombus bifarius        Bombus        bifarius
# 35         Bombus bimaculatus        Bombus     bimaculatus
# 47          Bombus flavifrons        Bombus      flavifrons
# 51        Bombus griseocollis        Bombus    griseocollis
# 57             Bombus lucorum        Bombus         lucorum
# 58         Bombus melanopygus        Bombus     melanopygus
# 59              Bombus mixtus        Bombus          mixtus
# 67         Bombus rotundiceps        Bombus     rotundiceps
# 68         Bombus rufocinctus        Bombus     rufocinctus
# 74           Bombus ternarius        Bombus       ternarius
# 75          Bombus terrestris        Bombus      terrestris
# 76           Bombus terricola        Bombus       terricola
# 77              Bombus vagans        Bombus          vagans
# 80        Bombus vosnesenskii        Bombus    vosnesenskii
# 88      Coelioxys octodentata     Coelioxys     octodentata
# 94        Halictus rubicundus      Halictus      rubicundus
# 96       Hoplitis pilosifrons      Hoplitis     pilosifrons
# 112   Lasioglossum fuscipenne  Lasioglossum      fuscipenne
# 116  Lasioglossum leucozonium  Lasioglossum     leucozonium
# 127          Megachile brevis     Megachile          brevis
# 128          Megachile exilis     Megachile          exilis
# 133       Megachile montivaga     Megachile       montivaga
# 136                Melissodes    Melissodes             NaN
# 137     Melissodes bimaculata    Melissodes      bimaculata
# 138     Melissodes comptoides    Melissodes      comptoides
# 139    Melissodes denticulata    Melissodes     denticulata
# 140       Melissodes desponsa    Melissodes        desponsa
# 142       Melissodes trinodis    Melissodes        trinodis
# 147          Nomada bidentata        Nomada       bidentata
# 156         Osmia atriventris         Osmia     atriventris
# 157           Osmia bucephala         Osmia       bucephala
#
#                          CommonName  \
# 29       White-shouldered Bumblebee
# 33          Golden-belted Bumblebee
# 34               Two-form Bumblebee
# 35            Two-spotted Bumblebee
# 47         Yellow-fronted Bumblebee
# 51           Brown-belted Bumblebee
# 57           White-tailed Bumblebee
# 58          Orange-rumped Bumblebee
# 59           Fuzzy-horned Bumblebee
# 67           Round-headed Bumblebee
# 68             Red-belted Bumblebee
# 74            Tri-colored Bumblebee
# 75            Buff-tailed Bumblebee
# 76          Yellow-banded Bumblebee
# 77             Half-black Bumblebee
# 80           Yellow-faced Bumblebee
# 88         Eight-toothed Cuckoo Bee
# 94           Broad-banded Sweat Bee
# 96             Hairy-faced Hoplitis
# 112          Dusky-winged Sweat Bee
# 116          White-banded Sweat Bee
# 127                Short-leafed Bee
# 128              Slender-leafed Bee
# 133  Mountain-loving Leafcutter Bee
# 136                 Long-horned Bee
# 137     Two-spotted Long-horned Bee
# 138    Well-behaved Long-horned Bee
# 139       Toothless Long-horned Bee
# 140      Despondent Long-horned Bee
# 142   Three-knobbed Long-horned Bee
# 147          Two-toothed Cuckoo Bee
# 156         Black-bellied Mason Bee
# 157          Large-headed Mason Bee
#
#                                            Description  \
# 29   Found in woodlands and gardens; enjoys clover ...
# 33   Found in western U.S.; prefers wildflowers and...
# 34   Found in various North American habitats; enjo...
# 35   Found in northeastern U.S.; enjoys clover and ...
# 47   Found in U.S.; enjoys wildflowers and garden p...
# 51   Found in eastern U.S.; enjoys clover and meado...
# 57   Found in Europe and Asia; enjoys clover and me...
# 58   Found in Europe and Asia; enjoys wildflowers a...
# 59   Found in U.S.; enjoys a variety of flowering p...
# 67   Found in Europe and Asia; prefers wildflowers ...
# 68   Found in Europe and Asia; enjoys clover and me...
# 74   Found in North America; enjoys wildflowers and...
# 75   Found in Europe and Asia; enjoys wildflowers a...
# 76   Found in northern U.S. and Canada; prefers wil...
# 77   Found in the U.S.; enjoys wildflowers and gard...
# 80   Found in North America; enjoys a variety of fl...
# 88   Found in U.S.; parasitizes nests of other bees...
# 94   Found in U.S.; enjoys sunflowers and goldenrod...
# 96   Found in meadows and forests; enjoys small flo...
# 112  Found in gardens and fields; enjoys asters and...
# 116  Found in U.S.; enjoys sunflowers and goldenrod...
# 127  Found in U.S.; enjoys a variety of flowering p...
# 128  Found in various U.S. habitats; enjoys small f...
# 133  Found in western U.S.; prefers wildflowers and...
# 136  Found in gardens and meadows; favors wildflowe...
# 137  Found in western U.S.; enjoys wildflowers and ...
# 138  Found in U.S.; favors wildflowers and garden p...
# 139  Found in U.S.; prefers wildflowers and garden ...
# 140  Found in U.S.; enjoys wildflowers and garden p...
# 142  Found in U.S.; favors wildflowers and garden p...
# 147  Found in northeastern U.S.; parasitizes nests ...
# 156  Found in woodlands and fields; enjoys small fl...
# 157  Found in western U.S.; enjoys small flowers; a...
#
#                                              Source
# 29                      Bumblebees of North America
# 33                      Bumblebees of North America
# 34                      Bumblebees of North America
# 35                      Bumblebees of North America
# 47                      Bumblebees of North America
# 51                      Bumblebees of North America
# 57                      Bumblebees of North America
# 58                      Bumblebees of North America
# 59                      Bumblebees of North America
# 67   Integrated Taxonomic Information System (ITIS)
# 68                      Bumblebees of North America
# 74                      Bumblebees of North America
# 75                      Bumblebees of North America
# 76                                    IUCN Red List
# 77                      Bumblebees of North America
# 80                      Bumblebees of North America
# 88                                         BugGuide
# 94                                         BugGuide
# 96                                    Discover Life
# 112                                        BugGuide
# 116                                   Discover Life
# 127                                   Discover Life
# 128                                        BugGuide
# 133                                   Discover Life
# 136                                   Discover Life
# 137                                   Discover Life
# 138                                        BugGuide
# 139                                        BugGuide
# 140                                   Discover Life
# 142                                        BugGuide
# 147                                        BugGuide
# 156                                   Discover Life
# 157                                        BugGuide

# %% [markdown]
# Breakdown
# this regex looks for:
#
# Words ending in "ed" or "ern" followed by a non-word character (like a space, hyphen, or punctuation).
#
# Or simply a hyphen (-) anywhere in the string.
#
# (?i) makes the pattern case-insensitive.
#
# \b ensures "ed" or "ern" appear at word boundaries, i.e., the end of a word.

# %%
df_regex.shape
# Out:
# (33, 6)

# %% [markdown]
# df_regex.shape is a Pandas DataFrame attribute that returns a tuple representing the dimensions of the DataFrame — specifically, the number of rows and columns.
#
# since df_regex.shape returns (33, 6), that means the filtered DataFrame df_regex has:
#
# 33 rows (bee records that matched the regex pattern), and
#
# 6 columns (like ScientificName, Species etc.).

# %% [markdown]
# ### Grouping Aggregating Data

# %%
import pandas as pd

# Read the North American bumblebee CSV file into a DataFrame for easy data manipulation and analysis, forcing column 6 and 16 to be strings
df1=pd.read_csv('/workspaces/myfolder/SASInnovate25/pattern_decline_N_American_Bumblebees.csv', dtype={6: str, 16: str}, encoding='latin-1')

# %%
df1.groupby(['scientificName','stateProvince']).size().reset_index(name='count').sort_values(by='count', ascending=False).head(20)
# Out:
#            scientificName stateProvince  count
# 629   Bombus vosnesenskii    California   8982
# 85        Bombus bifarius    California   2950
# 94        Bombus bifarius          Utah   2392
# 557      Bombus terricola      Michigan   2185
# 306      Bombus impatiens      Illinois   1723
# 410   Bombus occidentalis    California   1712
# 86        Bombus bifarius      Colorado   1594
# 634   Bombus vosnesenskii        Oregon   1588
# 92        Bombus bifarius        Oregon   1555
# 95        Bombus bifarius    Washington   1189
# 436  Bombus pensylvanicus      Illinois   1097
# 466  Bombus pensylvanicus         Texas   1071
# 96        Bombus bifarius       Wyoming   1016
# 270   Bombus griseocollis      Nebraska    947
# 424   Bombus occidentalis    Washington    937
# 87        Bombus bifarius         Idaho    935
# 449  Bombus pensylvanicus      Nebraska    880
# 421   Bombus occidentalis        Oregon    829
# 423   Bombus occidentalis          Utah    824
# 565      Bombus terricola      New York    813

# %% [markdown]
# This line of code performs a grouped count summary in Pandas and returns the top 20 combinations of scientific name and state/province by frequency, sorted in descending order.
#
# 🐝 In bee-speak: this is like tallying up how many times each bee species shows up in each state, ranking them from the most spotted to the least — the top 20 buzziest combos!

# %% [markdown]
# Explanation
# df1.groupby(['scientificName','stateProvince'])  # Group the DataFrame by both scientific name and state/province<br>
#    .size()                                       # Count the number of rows (i.e., bee observations) in each group<br>
#    .reset_index(name='count')                    # Convert the result to a DataFrame and name the count column 'count'<br>
#    .sort_values(by='count', ascending=False)     # Sort the counts from highest to lowest<br>
#    .head(20)                                     # Show only the top 20 results<br>
